# %% [markdown]
# <a href="https://colab.research.google.com/github/Durgasiv/dataclean/blob/main/Datacleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/drive/MyDrive/Data-Cleaning-master/Data-Cleaning-master/Datasets/GB_category_id.json', skipinitialspace=True)

# %%
data.tail()
# Out:
#                     {
# assignable: false NaN
# }                 NaN
# }                 NaN
# ]                 NaN
# }                 NaN

# %%
DataFrame_name = pd.DataFrame({'Column1': [1, 2, 3], 'Column2': ['a', 'b', 'c']})

# %%
right = pd.DataFrame({'Column3': [4, 5, 6], 'Column4': ['d', 'e', 'f']})

# %%
DataFrame_name = pd.DataFrame({'Column1': [1, 2, 3], 'Column2': [4, 5, 6]})
right = pd.DataFrame({'Column3': [7, 8, 9], 'Column4': [10, 11, 12]})

# %%
left_columns = DataFrame_name.columns
right_columns = right.columns

print("Left DataFrame columns:", left_columns)
print("Right DataFrame columns:", right_columns)
# Out:
# Left DataFrame columns: Index(['Column1', 'Column2'], dtype='object')
# Right DataFrame columns: Index(['Column3', 'Column4'], dtype='object')

# %%
if 'common_column' not in DataFrame_name.columns or 'common_column' not in right.columns:
    print('common_column not found in both DataFrames')
# Out:
# common_column not found in both DataFrames

# %%
    DataFrame_name['common_column'] = [None] * len(DataFrame_name)
    right['common_column'] = [None] * len(right)

# %%
if 'common_column' not in DataFrame_name.columns or 'common_column' not in right.columns:
    raise KeyError('common_column not found in both DataFrames')

# %%
merged_df = DataFrame_name.merge(right, how='inner', on='common_column')

# %%
data.isnull()
# Out:
#                                                        {
# kind: "youtube#videoCategoryListResponse"           True
# etag: "\"m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG...  True
# items: [                                            True
# {                                                   True
# kind: "youtube#videoCategory"                       True
# ...                                                  ...
# assignable: false                                   True
# }                                                   True
# }                                                   True
# ]                                                   True
# }                                                   True
#
# [315 rows x 1 columns]

# %%
data.isna()
# Out:
#                                                        {
# kind: "youtube#videoCategoryListResponse"           True
# etag: "\"m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG...  True
# items: [                                            True
# {                                                   True
# kind: "youtube#videoCategory"                       True
# ...                                                  ...
# assignable: false                                   True
# }                                                   True
# }                                                   True
# ]                                                   True
# }                                                   True
#
# [315 rows x 1 columns]

# %%
data.isna().any()
# Out:
# {    True
# dtype: bool

# %%
data.isna().sum()
# Out:
# {    315
# dtype: int64

# %%
data.isna().any().sum()
# Out:
# 1

# %%
print(DataFrame_name)

DataFrame_name.info()
DataFrame_name.head()
DataFrame_name.dtypes
for column in DataFrame_name.columns:
    DataFrame_name[column].fillna(DataFrame_name[column].mean(), inplace=True)
DataFrame_name.isnull().sum()
DataFrame_name.fillna(value=0)
DataFrame_name.fillna(DataFrame_name.mean())
DataFrame_name.fillna(DataFrame_name.median())
# Out:
#    Column1  Column2 common_column
# 0        1        4          None
# 1        2        5          None
# 2        3        6          None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Column1        3 non-null      int64
#  1   Column2        3 non-null      int64
#  2   common_column  0 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 200.0+ bytes
#    Column1  Column2  common_column
# 0        1        4            NaN
# 1        2        5            NaN
# 2        3        6            NaN

# %%
DataFrame_name.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Column1        3 non-null      int64
#  1   Column2        3 non-null      int64
#  2   common_column  0 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 200.0 bytes

# %%
print(type(DataFrame_name.mean(axis=1)))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print('commo' in DataFrame_name.columns)
# Out:
# False

# %%
if 'commo' in DataFrame_name.columns:
    DataFrame_name.fillna(axis=1, value=DataFrame_name['commo'].mean(), inplace=True)
else:
    print("The 'commo' column does not exist in the DataFrame.")
# Out:
# The 'commo' column does not exist in the DataFrame.

# %%
print(DataFrame_name.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Column1        3 non-null      int64
#  1   Column2        3 non-null      int64
#  2   common_column  0 non-null      float64
# dtypes: float64(1), int64(2)
# memory usage: 200.0 bytes
# None

# %%
DataFrame_name = pd.DataFrame(DataFrame_name)

# %%
DataFrame_name.fillna(value=0, axis=0)
DataFrame_name.fillna(method='ffill', axis=1)
# Out:
#    Column1  Column2  common_column
# 0      1.0      4.0            4.0
# 1      2.0      5.0            5.0
# 2      3.0      6.0            6.0

# %%
DataFrame_name.fillna(value=DataFrame_name.mean())
# Out:
#    Column1  Column2  common_column
# 0        1        4            NaN
# 1        2        5            NaN
# 2        3        6            NaN

# %%
DataFrame_name.fillna(method="backfill", inplace=True)

# %%
DataFrame_name.fillna(value=DataFrame_name.mean(), inplace=True)

# %%
DataFrame_name.fillna(method='ffill')  # Fill missing values with the previous value
# Out:
#    Column1  Column2  common_column
# 0        1        4            0.0
# 1        2        5            0.0
# 2        3        6            0.0

# %%
DataFrame_name.fillna(value=0, method=None, axis=None, inplace=False, limit=None, downcast=None)
# Out:
#    Column1  Column2  common_column
# 0        1        4            0.0
# 1        2        5            0.0
# 2        3        6            0.0

# %%
data.duplicated()
# Out:
# kind: "youtube#videoCategoryListResponse"                              False
# etag: "\"m2yskBQFythfE4irbTIeOgYYfBU/1v2mrzYSYG6onNLt2qTj13hkQZk\""     True
# items: [                                                                True
# {                                                                       True
# kind: "youtube#videoCategory"                                           True
#                                                                        ...
# assignable: false                                                       True
# }                                                                       True
# }                                                                       True
# ]                                                                       True
# }                                                                       True
# Length: 315, dtype: bool

# %%
DataFrame_name.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#    Column1  Column2  common_column
# 0        1        4            0.0
# 1        2        5            0.0
# 2        3        6            0.0
